# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('WorldCupMatches.csv')
dataset
# Out:
#         Year              Datetime              Stage  \
# 0     1930.0  13 Jul 1930 - 15:00             Group 1
# 1     1930.0  13 Jul 1930 - 15:00             Group 4
# 2     1930.0  14 Jul 1930 - 12:45             Group 2
# 3     1930.0  14 Jul 1930 - 14:50             Group 3
# 4     1930.0  15 Jul 1930 - 16:00             Group 1
# 5     1930.0  16 Jul 1930 - 14:45             Group 1
# 6     1930.0  17 Jul 1930 - 12:45             Group 2
# 7     1930.0  17 Jul 1930 - 14:45             Group 4
# 8     1930.0  18 Jul 1930 - 14:30             Group 3
# 9     1930.0  19 Jul 1930 - 12:50             Group 1
# 10    1930.0  19 Jul 1930 - 15:00             Group 1
# 11    1930.0  20 Jul 1930 - 13:00             Group 2
# 12    1930.0  20 Jul 1930 - 15:00             Group 4
# 13    1930.0  21 Jul 1930 - 14:50             Group 3
# 14    1930.0  22 Jul 1930 - 14:45             Group 1
# 15    1930.0  26 Jul 1930 - 14:45         Semi-finals
# ...

# %%
dataset.shape
# Out:
# (4572, 20)

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=4572, step=1)

# %%
#first 5 lines
dataset.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
dataset.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
dataset.info
# Out:
# <bound method DataFrame.info of        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# 5    1930.0  16 Jul 1930 - 14:45                    Group 1
# 6    1930.0  17 Jul 1930 - 12:45                    Group 2
# 7    1930.0  17 Jul 1930 - 14:45                    Group 4
# 8    1930.0  18 Jul 1930 - 14:30                    Group 3
# 9    1930.0  19 Jul 1930 - 12:50                    Group 1
# 10   1930.0  19 Jul 1930 - 15:00                    Group 1
# 11   1930.0  20 Jul 1930 - 13:00                    Group 2
# 12   1930.0  20 Jul 1930 - 15:00                    Group 4
# 13   1930.0  21 Jul 1930 - 14:50                    Group 3
# ...

# %%
#knowing null value set
dataset.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
'''
1st method:dropna:
1. deletes a row if it has a null value for a particular feature
2. deletes a particular column if it has more than 75% missing values
'''
#advised only if enough samples in dataset exist
dataset.dropna(inplace =True)

# %%
dataset.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
dataset.shape
# Out:
# (850, 20)

# %%
'''
method 2 of removing NaN:
replace it with mean, median or mode
'''
dataset['Year'].mean()
# Out:
# 1985.0211764705882

# %%
#viewing last 5 items
dataset['Year'].tail()
# Out:
# 847    2014.0
# 848    2014.0
# 849    2014.0
# 850    2014.0
# 851    2014.0
# Name: Year, dtype: float64

# %%
#replacing
dataset['Year'].replace(np.NaN,dataset['Year'].mean()).tail()
# Out:
# 847    2014.0
# 848    2014.0
# 849    2014.0
# 850    2014.0
# 851    2014.0
# Name: Year, dtype: float64

# %%
#as ML uses mathematical equations, set the catagorical values also
datanew = pd.read_csv('Data.csv')
datanew
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#so we have to change yes and no to 0 & 1
datanew.Purchased.replace(('Yes','No'), (1, 0), inplace=True)
datanew
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 4  Germany  40.0      NaN          1
# 5   France  35.0  58000.0          1
# 6    Spain   NaN  52000.0          0
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %%
X = datanew.iloc[:, :-1].values
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
datanew.dropna(inplace=True)

# %%
datanew.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
datanew
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 5   France  35.0  58000.0          1
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %%
X[:,0]
# Out:
# array(['France', 'Spain', 'Germany', 'Spain', 'Germany', 'France',
#        'Spain', 'France', 'Germany', 'France'], dtype=object)

# %%
'''
working on catagorical values
so we encode the catagorial variables
catagorical to numerical data we use LabelEncoder() class
from pre processing lib
'''
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
#removing any NaN values
X = datanew.iloc[:,:-1].values
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['France', 35.0, 58000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
#converting to catagorical
X[:,0] = label_encoder.fit_transform(X[:,0])
X=np.array(X,dtype='int32')

# %%
#0,1,2 are catagorical values of resp. countries
X
# Out:
# array([[    0,    44, 72000],
#        [    2,    27, 48000],
#        [    1,    30, 54000],
#        [    2,    38, 61000],
#        [    0,    35, 58000],
#        [    0,    48, 79000],
#        [    1,    50, 83000],
#        [    0,    37, 67000]])

# %%
#another method
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder(categorical_features=[0])

# %%
x = onehotencoder.fit_transform(X)
print(x)
# Out:
#   (0, 0)	1.0
#   (1, 2)	1.0
#   (2, 1)	1.0
#   (3, 2)	1.0
#   (4, 0)	1.0
#   (5, 0)	1.0
#   (6, 1)	1.0
#   (7, 0)	1.0
#   (0, 3)	44.0
#   (0, 4)	72000.0
#   (1, 3)	27.0
#   (1, 4)	48000.0
#   (2, 3)	30.0
#   (2, 4)	54000.0
#   (3, 3)	38.0
#   (3, 4)	61000.0
#   (4, 3)	35.0
#   (4, 4)	58000.0
#   (5, 3)	48.0
#   (5, 4)	79000.0
#   (6, 3)	50.0
#   (6, 4)	83000.0
#   (7, 3)	37.0
#   (7, 4)	67000.0

# %%
datanew
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 5   France  35.0  58000.0          1
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %%
dummy = pd.get_dummies(datanew['Country'])
dummy
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       0        1      0
# 3       0        0      1
# 5       1        0      0
# 7       1        0      0
# 8       0        1      0
# 9       1        0      0

# %%
datanew = pd.concat([datanew,dummy],axis=1)
datanew
# Out:
#    Country   Age   Salary  Purchased  France  Germany  Spain
# 0   France  44.0  72000.0          0       1        0      0
# 1    Spain  27.0  48000.0          1       0        0      1
# 2  Germany  30.0  54000.0          0       0        1      0
# 3    Spain  38.0  61000.0          0       0        0      1
# 5   France  35.0  58000.0          1       1        0      0
# 7   France  48.0  79000.0          1       1        0      0
# 8  Germany  50.0  83000.0          0       0        1      0
# 9   France  37.0  67000.0          1       1        0      0

# %%
datanew = datanew.drop(['Country'],axis = 1)
datanew
# Out:
#     Age   Salary  Purchased  France  Germany  Spain
# 0  44.0  72000.0          0       1        0      0
# 1  27.0  48000.0          1       0        0      1
# 2  30.0  54000.0          0       0        1      0
# 3  38.0  61000.0          0       0        0      1
# 5  35.0  58000.0          1       1        0      0
# 7  48.0  79000.0          1       1        0      0
# 8  50.0  83000.0          0       0        1      0
# 9  37.0  67000.0          1       1        0      0

# %%
datanew.dropna(inplace = True)
y = datanew.iloc[:,2].values
y
# Out:
# array([0, 1, 0, 0, 1, 1, 0, 1], dtype=int64)

# %%
 #from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)
X_train
# Out:
# array([[    2,    38, 61000],
#        [    0,    37, 67000],
#        [    1,    50, 83000],
#        [    2,    27, 48000],
#        [    0,    35, 58000],
#        [    0,    44, 72000]])

# %%
 X_test
# Out:
# array([[    0,    48, 79000],
#        [    1,    30, 54000]])

# %%
y_train
# Out:
# array([0, 1, 0, 1, 1, 0], dtype=int64)
